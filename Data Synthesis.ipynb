# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
im = Image.open('DATA/raw/mid1.png').convert('RGB').resize((720,720))
im = np.array(im)

# %%
plt.imshow(im)
plt.show()

# %% [markdown]
# # Train Set

# %%
pieces = [im[i*90:i*90+90, j*90:j*90+90] for i in range(8) for j in range(8)]
#pieces = pieces[:18] + pieces[48:]

# %%
len(pieces)
# Out:
# 64

# %%
plt.imshow(pieces[19])
plt.show()

# %%
for i, p in enumerate(pieces):
    p = Image.fromarray(p, mode='RGB')
    p.save(f'DATA/pieces/i{i}.png')
